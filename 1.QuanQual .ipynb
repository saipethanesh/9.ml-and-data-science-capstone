# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("smartphonesdata.csv")

# %%
dataset
# Out:
#        price  rating  has_5g  has_nfc  has_ir_blaster  num_cores  \
# 0    54999.0    89.0     1.0      1.0             0.0        8.0
# 1    19989.0    81.0     1.0      0.0             0.0        8.0
# 2    16499.0    75.0     1.0      0.0             0.0        8.0
# 3    24999.0    82.0     1.0      0.0             0.0        8.0
# 4    16999.0    80.0     1.0      1.0             0.0        8.0
# ..       ...     ...     ...      ...             ...        ...
# 854      NaN     NaN     NaN      NaN             NaN        NaN
# 855      NaN     NaN     NaN      NaN             NaN        NaN
# 856      NaN     NaN     NaN      NaN             NaN        NaN
# 857      NaN     NaN     NaN      NaN             NaN        NaN
# 858      NaN     NaN     NaN      NaN             NaN        NaN
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 0                3.2            5000.0                      1.0
# 1                2.2            5000.0                      1.0
# 2                2.4            5000.0                      1.0
# 3                2.6            5000.0                      1.0
# 4                2.2            5000.0                      1.0
# ..               ...               ...                      ...
# 854              NaN               NaN                      NaN
# 855              NaN               NaN                      NaN
# 856              NaN               NaN                      NaN
# 857              NaN               NaN                      NaN
# 858              NaN               NaN                      NaN
#
#      fast_charging  ...  primary_camera_rear  primary_camera_front  \
# 0            100.0  ...                 50.0                  16.0
# 1             33.0  ...                 64.0                  16.0
# 2             15.0  ...                 50.0                  13.0
# 3             67.0  ...                108.0                  16.0
# 4             25.0  ...                 50.0                   8.0
# ..             ...  ...                  ...                   ...
# 854            NaN  ...                  NaN                   NaN
# 855            NaN  ...                  NaN                   NaN
# 856            NaN  ...                  NaN                   NaN
# 857            NaN  ...                  NaN                   NaN
# 858            NaN  ...                  NaN                   NaN
#
#      extended_memory_available  extended_upto  resolution_width  \
# 0                          0.0            0.0            1440.0
# 1                          1.0         1024.0            1080.0
# 2                          1.0         1024.0            1080.0
# 3                          0.0            0.0            1080.0
# 4                          1.0         1024.0            1080.0
# ..                         ...            ...               ...
# 854                        NaN            NaN               NaN
# 855                        NaN            NaN               NaN
# 856                        NaN            NaN               NaN
# 857                        NaN            NaN               NaN
# 858                        NaN            NaN               NaN
#
#      resolution_height  brand_name                                    model  \
# 0               3216.0     oneplus                            OnePlus 11 5G
# 1               2412.0     oneplus                OnePlus Nord CE 2 Lite 5G
# 2               2408.0     samsung                    Samsung Galaxy A14 5G
# 3               2412.0         NaN                                      NaN
# 4               2408.0      realme                       Realme 10 Pro Plus
# ..                 ...         ...                                      ...
# 854                NaN      realme  Realme Narzo 50i Prime (4GB RAM + 64GB)
# 855                NaN        oppo                             Oppo Find X6
# 856                NaN    motorola               Motorola Moto Edge S30 Pro
# 857                NaN       honor                              Honor X8 5G
# 858                NaN        poco          POCO X4 GT 5G (8GB RAM + 256GB)
#
#      processor_brand       os
# 0         snapdragon  android
# 1         snapdragon  android
# 2             exynos  android
# 3                NaN      NaN
# 4          dimensity  android
# ..               ...      ...
# 854            tiger  android
# 855       snapdragon  android
# 856       snapdragon  android
# 857       snapdragon  android
# 858        dimensity  android
#
# [859 rows x 26 columns]

# %%
dataset.info()
dataset = dataset.convert_dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-79f6a117abb9> in <module>
# ----> 1 dataset.info()
#       2 dataset = dataset.convert_dtypes()
#
# C:\anaconda3\envs\AIML\lib\site-packages\pandas\core\frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2570                 if "object" in counts or self.index._is_memory_usage_qualified():
#    2571                     size_qualifier = "+"
# -> 2572             mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2573             lines.append(
#    2574                 "memory usage: {mem}\n".format(
#
# C:\anaconda3\envs\AIML\lib\site-packages\pandas\core\frame.py in memory_usage(self, index, deep)
#    2668         )
#    2669         if index:
# -> 2670             result = Series(self.index.memory_usage(deep=deep), index=["Index"]).append(
#    2671                 result
#    2672             )
#
# C:\anaconda3\envs\AIML\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     312                     data = data.copy()
#     313             else:
# --> 314                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     315
#     316                 data = SingleBlockManager(data, index, fastpath=True)
#
# C:\anaconda3\envs\AIML\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     710                 value = maybe_cast_to_datetime(value, dtype)
#     711
# --> 712             subarr = construct_1d_arraylike_from_scalar(value, len(index), dtype)
#     713
#     714         else:
#
# C:\anaconda3\envs\AIML\lib\site-packages\pandas\core\dtypes\cast.py in construct_1d_arraylike_from_scalar(value, length, dtype)
#    1231                 value = ensure_str(value)
#    1232
# -> 1233         subarr = np.empty(length, dtype=dtype)
#    1234         subarr.fill(value)
#    1235
#
# TypeError: Cannot interpret '<attribute 'dtype' of 'numpy.generic' objects>' as a data type

# %%
#Quan=["ssc_p","hsc_p","etest_p","degree_p","mba_p","salary"]
#Qual=["gender","ssc_b","hsc_b","degree_t"]

# %%
dataset.columns

# %%
dir(dataset)

# %%
dataset["ssc_p"].dtypes

# %%
for columnName in dataset.columns:
    print(columnName)

# %%
if(dataset["ssc_p"].dtype=='O'):
    print("qual")
else:
    print("quan")

# %%
quan=[]
qual=[]
for columnName in dataset.columns:
    #print(columnName)
    if(dataset[columnName].dtype=='O'):
        #print("qual")
        qual.append(columnName)
    else:
        #print("quan")
        quan.append(columnName)

# %%
quan

# %%
qual

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quanQual(dataset)

# %%
quan,qual=quanQual(dataset)

# %%
quan

# %%
qual
