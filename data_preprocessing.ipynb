# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
##Importing the libraries

# %%
dataset=pd.read_csv("smartphones.csv")

# %%
dataset
# Out:
#        price  rating  has_5g  has_nfc  has_ir_blaster  num_cores  \
# 0    54999.0    89.0     1.0      1.0             0.0        8.0
# 1    19989.0    81.0     1.0      0.0             0.0        8.0
# 2    16499.0    75.0     1.0      0.0             0.0        8.0
# 3    24999.0    82.0     1.0      0.0             0.0        8.0
# 4    16999.0    80.0     1.0      1.0             0.0        8.0
# ..       ...     ...     ...      ...             ...        ...
# 854      NaN     NaN     NaN      NaN             NaN        NaN
# 855      NaN     NaN     NaN      NaN             NaN        NaN
# 856      NaN     NaN     NaN      NaN             NaN        NaN
# 857      NaN     NaN     NaN      NaN             NaN        NaN
# 858      NaN     NaN     NaN      NaN             NaN        NaN
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 0                3.2            5000.0                      1.0
# ...

# %%
dataset.isnull().sum()
# Out:
# price                        181
# rating                       181
# has_5g                       181
# has_nfc                      181
# has_ir_blaster               181
# num_cores                    181
# processor_speed              181
# battery_capacity             181
# fast_charging_available      181
# fast_charging                181
# ram_capacity                 181
# internal_memory              181
# screen_size                  181
# refresh_rate                 181
# num_rear_cameras             181
# num_front_cameras            181
# primary_camera_rear          181
# primary_camera_front         181
# extended_memory_available    181
# extended_upto                181
# resolution_width             181
# resolution_height            181
# brand_name                   181
# model                        181
# processor_brand              181
# os                           181
# dtype: int64

# %%
dataset.isna().sum()
# Out:
# price                        181
# rating                       181
# has_5g                       181
# has_nfc                      181
# has_ir_blaster               181
# num_cores                    181
# processor_speed              181
# battery_capacity             181
# fast_charging_available      181
# fast_charging                181
# ram_capacity                 181
# internal_memory              181
# screen_size                  181
# refresh_rate                 181
# num_rear_cameras             181
# num_front_cameras            181
# primary_camera_rear          181
# primary_camera_front         181
# extended_memory_available    181
# extended_upto                181
# resolution_width             181
# resolution_height            181
# brand_name                   181
# model                        181
# processor_brand              181
# os                           181
# dtype: int64

# %%
dataset["processor_brand"].fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# price                        181
# rating                       181
# has_5g                       181
# has_nfc                      181
# has_ir_blaster               181
# num_cores                    181
# processor_speed              181
# battery_capacity             181
# fast_charging_available      181
# fast_charging                181
# ram_capacity                 181
# internal_memory              181
# screen_size                  181
# refresh_rate                 181
# num_rear_cameras             181
# num_front_cameras            181
# primary_camera_rear          181
# primary_camera_front         181
# extended_memory_available    181
# extended_upto                181
# resolution_width             181
# resolution_height            181
# brand_name                   181
# model                        181
# processor_brand                0
# os                           181
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#        price  rating  has_5g  has_nfc  has_ir_blaster  num_cores  \
# 0    54999.0    89.0     1.0      1.0             0.0        8.0
# 1    19989.0    81.0     1.0      0.0             0.0        8.0
# 2    16499.0    75.0     1.0      0.0             0.0        8.0
# 4    16999.0    80.0     1.0      1.0             0.0        8.0
# 5    29999.0    86.0     1.0      0.0             1.0        8.0
# ..       ...     ...     ...      ...             ...        ...
# 671  49990.0    89.0     1.0      1.0             0.0        8.0
# 672  32990.0    86.0     1.0      1.0             1.0        8.0
# 673   8720.0    64.0     0.0      0.0             0.0        8.0
# 674  69990.0    89.0     1.0      1.0             0.0        8.0
# 677  28990.0    85.0     1.0      1.0             1.0        8.0
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 0               3.20            5000.0                      1.0
# ...

# %%
dataset["processor_brand"].fillna(dataset["processor_brand"].mean(),inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\anaconda3\envs\AIML\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1303         try:
# -> 1304             x = float(x)
#    1305         except Exception:
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\anaconda3\envs\AIML\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1306             try:
# -> 1307                 x = complex(x)
#    1308             except Exception:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
dataset
# Out:
#        price  rating  has_5g  has_nfc  has_ir_blaster  num_cores  \
# 0    54999.0    89.0     1.0      1.0             0.0        8.0
# 1    19989.0    81.0     1.0      0.0             0.0        8.0
# 2    16499.0    75.0     1.0      0.0             0.0        8.0
# 4    16999.0    80.0     1.0      1.0             0.0        8.0
# 5    29999.0    86.0     1.0      0.0             1.0        8.0
# ..       ...     ...     ...      ...             ...        ...
# 671  49990.0    89.0     1.0      1.0             0.0        8.0
# 672  32990.0    86.0     1.0      1.0             1.0        8.0
# 673   8720.0    64.0     0.0      0.0             0.0        8.0
# 674  69990.0    89.0     1.0      1.0             0.0        8.0
# 677  28990.0    85.0     1.0      1.0             1.0        8.0
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 0               3.20            5000.0                      1.0
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qaul=quanQual(dataset)

# %%
dataset[quan]
# Out:
#        price  rating  has_5g  has_nfc  has_ir_blaster  num_cores  \
# 0    54999.0    89.0     1.0      1.0             0.0        8.0
# 1    19989.0    81.0     1.0      0.0             0.0        8.0
# 2    16499.0    75.0     1.0      0.0             0.0        8.0
# 4    16999.0    80.0     1.0      1.0             0.0        8.0
# 5    29999.0    86.0     1.0      0.0             1.0        8.0
# ..       ...     ...     ...      ...             ...        ...
# 671  49990.0    89.0     1.0      1.0             0.0        8.0
# 672  32990.0    86.0     1.0      1.0             1.0        8.0
# 673   8720.0    64.0     0.0      0.0             0.0        8.0
# 674  69990.0    89.0     1.0      1.0             0.0        8.0
# 677  28990.0    85.0     1.0      1.0             1.0        8.0
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 0               3.20            5000.0                      1.0
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])
df = pd.DataFrame(df,columns = quan)

# %%
df
# Out:
#        price  rating  has_5g  has_nfc  has_ir_blaster  num_cores  \
# 0    54999.0    89.0     1.0      1.0             0.0        8.0
# 1    19989.0    81.0     1.0      0.0             0.0        8.0
# 2    16499.0    75.0     1.0      0.0             0.0        8.0
# 3    16999.0    80.0     1.0      1.0             0.0        8.0
# 4    29999.0    86.0     1.0      0.0             1.0        8.0
# ..       ...     ...     ...      ...             ...        ...
# 492  49990.0    89.0     1.0      1.0             0.0        8.0
# 493  32990.0    86.0     1.0      1.0             1.0        8.0
# 494   8720.0    64.0     0.0      0.0             0.0        8.0
# 495  69990.0    89.0     1.0      1.0             0.0        8.0
# 496  28990.0    85.0     1.0      1.0             1.0        8.0
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 0               3.20            5000.0                      1.0
# ...

# %%
df
# Out:
#        price  rating  has_5g  has_nfc  has_ir_blaster  num_cores  \
# 0    54999.0    89.0     1.0      1.0             0.0        8.0
# 1    19989.0    81.0     1.0      0.0             0.0        8.0
# 2    16499.0    75.0     1.0      0.0             0.0        8.0
# 3    16999.0    80.0     1.0      1.0             0.0        8.0
# 4    29999.0    86.0     1.0      0.0             1.0        8.0
# ..       ...     ...     ...      ...             ...        ...
# 492  49990.0    89.0     1.0      1.0             0.0        8.0
# 493  32990.0    86.0     1.0      1.0             1.0        8.0
# 494   8720.0    64.0     0.0      0.0             0.0        8.0
# 495  69990.0    89.0     1.0      1.0             0.0        8.0
# 496  28990.0    85.0     1.0      1.0             1.0        8.0
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 0               3.20            5000.0                      1.0
# ...

# %%
cate=dataset[qaul]

# %%
cate
# Out:
#     brand_name                                    model processor_brand  \
# 0      oneplus                            OnePlus 11 5G      snapdragon
# 1      oneplus                OnePlus Nord CE 2 Lite 5G      snapdragon
# 2      samsung                    Samsung Galaxy A14 5G          exynos
# 4       realme                       Realme 10 Pro Plus       dimensity
# 5      samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)      snapdragon
# ..         ...                                      ...             ...
# 671       poco                              Poco M6 Pro       dimensity
# 672       oppo                              OPPO A97 5G       dimensity
# 673    samsung                       Samsung Galaxy A24          exynos
# 674    infinix                      Infinix Note 13 Pro           helio
# 677       sony                      Sony Xperia 5 IV 5G      snapdragon
#
#           os
# 0    android
# 1    android
# 2    android
# 4    android
# 5    android
# ..       ...
# ...

# %%
two=[df,cate]

# %%
preprocessed=pd.concat(two,axis=1)

# %%
preprocessed
# Out:
#        price  rating  has_5g  has_nfc  has_ir_blaster  num_cores  \
# 0    54999.0    89.0     1.0      1.0             0.0        8.0
# 1    19989.0    81.0     1.0      0.0             0.0        8.0
# 2    16499.0    75.0     1.0      0.0             0.0        8.0
# 3    16999.0    80.0     1.0      1.0             0.0        8.0
# 4    29999.0    86.0     1.0      0.0             1.0        8.0
# ..       ...     ...     ...      ...             ...        ...
# 671      NaN     NaN     NaN      NaN             NaN        NaN
# 672      NaN     NaN     NaN      NaN             NaN        NaN
# 673      NaN     NaN     NaN      NaN             NaN        NaN
# 674      NaN     NaN     NaN      NaN             NaN        NaN
# 677      NaN     NaN     NaN      NaN             NaN        NaN
#
#      processor_speed  battery_capacity  fast_charging_available  \
# 0                3.2            5000.0                      1.0
# ...

# %%
preprocessed.isnull().sum()
# Out:
# price                        136
# rating                       136
# has_5g                       136
# has_nfc                      136
# has_ir_blaster               136
# num_cores                    136
# processor_speed              136
# battery_capacity             136
# fast_charging_available      136
# fast_charging                136
# ram_capacity                 136
# internal_memory              136
# screen_size                  136
# refresh_rate                 136
# num_rear_cameras             136
# num_front_cameras            136
# primary_camera_rear          136
# primary_camera_front         136
# extended_memory_available    136
# extended_upto                136
# resolution_width             136
# resolution_height            136
# brand_name                   136
# model                        136
# processor_brand              136
# os                           136
# dtype: int64

# %%
preprocessed.to_csv("smartphonesdata.csv",index=False)
